# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
sonar_df = pd.read_csv('sonarData.csv', header=None)
sonar_df
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
sonar_df.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   R
# 1  0.0052  0.0044   R
# 2  0.0095  0.0078   R
# ...

# %%
sonar_df.tail()
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
#          9   ...      51      52      53      54      55      56      57  \
# 203  0.2684  ...  0.0116  0.0098  0.0199  0.0033  0.0101  0.0065  0.0115
# 204  0.2154  ...  0.0061  0.0093  0.0135  0.0063  0.0063  0.0034  0.0032
# 205  0.2529  ...  0.0160  0.0029  0.0051  0.0062  0.0089  0.0140  0.0138
# 206  0.2354  ...  0.0086  0.0046  0.0126  0.0036  0.0035  0.0034  0.0079
# 207  0.2354  ...  0.0146  0.0129  0.0047  0.0039  0.0061  0.0040  0.0036
#
#          58      59  60
# 203  0.0193  0.0157   M
# ...

# %%
sonar_df.dtypes
# Out:
# 0     float64
# 1     float64
# 2     float64
# 3     float64
# 4     float64
#        ...
# 56    float64
# 57    float64
# 58    float64
# 59    float64
# 60     object
# Length: 61, dtype: object

# %% [markdown]
# Observtions:
#     1. All the columns in dataset are numeric
#     2. The target coulumn is categorical

# %%
sonar_df.describe()
# Out:
#                0           1           2           3           4           5   \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                6           7           8           9   ...          50  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.121747    0.134799    0.178003    0.208259  ...    0.016069
# ...

# %%
duplicate_rows_df = sonar_df[sonar_df.duplicated()]
print(duplicate_rows_df.shape)
# Out:
# (0, 61)

# %% [markdown]
# There are no duplicate values in any row

# %% [markdown]
# We can plot some box plot which will give us more clear picture of outliers

# %%
sonar_df.plot.box(figsize=(12,7))
plt.title('Boxplots of all frequency')
plt.xlabel('Frequency')
plt.ylabel('Power spectral density (normalized)')
plt.show()

# %% [markdown]
# With this visual it seems that much of our data is normalised already

# %%
#Changin the target value data type to int64
sonar_df[60].replace(['R','M'],[0,1],inplace=True)

# %%
sonar_df
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
corr_matrix= sonar_df.corr()
fig = plt.gcf()  # or by other means, like plt.subplots
figsize = fig.get_size_inches()
fig.set_size_inches(figsize * 4)
sns.heatmap(corr_matrix, annot=True, cmap='winter')

# %% [markdown]
# The plot says that much of our data is correrelated to each other.

# %%
# plotting distribution plot of the column
for i, column in enumerate(sonar_df.columns, 1):
    plt.subplot(10,7,i)
    sns.distplot(sonar_df[column])

# %% [markdown]
# This plot shows that much of our data is correlated to each other. We may drop the correlated columns if needed.
# We will see how the model behaves and might check the accuracy if it increases after we drop the columns.

# %%
from sklearn import preprocessing

# separate the data from the target attributes
Y = sonar_df[60]
X = sonar_df.drop(60,axis=1)
# normalize the data attributes
normalized_X = preprocessing.normalize(X)

# %%
x=pd.DataFrame(normalized_X,columns=X.columns)

# %%
x
# Out:
#            0         1         2         3         4         5         6   \
# 0    0.006765  0.012550  0.014478  0.007002  0.032271  0.033353  0.052059
# 1    0.015166  0.017509  0.028222  0.023066  0.039604  0.086474  0.072178
# 2    0.007289  0.016192  0.030576  0.030131  0.027098  0.063433  0.067634
# 3    0.003522  0.006022  0.021940  0.007220  0.007220  0.012960  0.038669
# 4    0.027636  0.024154  0.017444  0.014289  0.021398  0.023537  0.043847
# ..        ...       ...       ...       ...       ...       ...       ...
# 203  0.006377  0.011798  0.005729  0.006036  0.013401  0.055582  0.069154
# 204  0.010495  0.003282  0.009682  0.018325  0.024693  0.031126  0.032166
# 205  0.017500  0.014650  0.006035  0.009789  0.011767  0.039258  0.042141
# 206  0.010569  0.012313  0.017092  0.021208  0.005825  0.047230  0.051102
# 207  0.008717  0.012170  0.004560  0.009119  0.007175  0.011332  0.021960
#
#            7         8         9   ...        50        51        52  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score,confusion_matrix, classification_report,roc_auc_score,roc_curve
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier,RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %%
best_rstate=0
accu=0
for i in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(normalized_X,Y,test_size=0.20,random_state=i)
    mod=LogisticRegression()
    mod.fit(x_train,y_train)
    y_pred=mod.predict(x_test)
    tempaccu=accuracy_score(y_test,y_pred)
    if tempaccu>accu:
        accu=tempaccu
        best_rstate=i

print(f"Best Accuracy {accu*100} found at random state {best_rstate} ")
# Out:
# Best Accuracy 83.33333333333334 found at random state 42

# %%
best_rstate=0
accu=0
for i in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(normalized_X,Y,test_size=0.25,random_state=i)
    mod=DecisionTreeClassifier()
    mod.fit(x_train,y_train)
    y_pred=mod.predict(x_test)
    tempaccu=accuracy_score(y_test,y_pred)
    if tempaccu>accu:
        accu=tempaccu
        best_rstate=i

print(f"Best Accuracy {accu*100} found at random state {best_rstate} ")
# Out:
# Best Accuracy 84.61538461538461 found at random state 48

# %%
best_rstate=0
accu=0
for i in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(normalized_X,Y,test_size=0.25,random_state=i)
    mod=KNeighborsClassifier()
    mod.fit(x_train,y_train)
    y_pred=mod.predict(x_test)
    tempaccu=accuracy_score(y_test,y_pred)
    if tempaccu>accu:
        accu=tempaccu
        best_rstate=i

print(f"Best Accuracy {accu*100} found at random state {best_rstate} ")
# Out:
# Best Accuracy 90.38461538461539 found at random state 95

# %%
best_rstate=0
accu=0
for i in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(normalized_X,Y,test_size=0.25,random_state=i)
    mod=SVC()
    mod.fit(x_train,y_train)
    y_pred=mod.predict(x_test)
    tempaccu=accuracy_score(y_test,y_pred)
    if tempaccu>accu:
        accu=tempaccu
        best_rstate=i

print(f"Best Accuracy {accu*100} found at random state {best_rstate} ")
# Out:
# Best Accuracy 71.15384615384616 found at random state 54

# %%
best_rstate=0
accu=0
for i in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(normalized_X,Y,test_size=0.25,random_state=i)
    mod=AdaBoostClassifier()
    mod.fit(x_train,y_train)
    y_pred=mod.predict(x_test)
    tempaccu=accuracy_score(y_test,y_pred)
    if tempaccu>accu:
        accu=tempaccu
        best_rstate=i

print(f"Best Accuracy {accu*100} found at random state {best_rstate} ")
# Out:
# Best Accuracy 88.46153846153845 found at random state 48

# %%
best_rstate=0
accu=0
for i in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(normalized_X,Y,test_size=0.25,random_state=i)
    mod=RandomForestClassifier()
    mod.fit(x_train,y_train)
    y_pred=mod.predict(x_test)
    tempaccu=accuracy_score(y_test,y_pred)
    if tempaccu>accu:
        accu=tempaccu
        best_rstate=i

print(f"Best Accuracy {accu*100} found at random state {best_rstate} ")
# Out:
# Best Accuracy 88.46153846153845 found at random state 95

# %%
best_rstate=0
accu=0
for i in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(normalized_X,Y,test_size=0.25,random_state=i)
    mod=GradientBoostingClassifier()
    mod.fit(x_train,y_train)
    y_pred=mod.predict(x_test)
    tempaccu=accuracy_score(y_test,y_pred)
    if tempaccu>accu:
        accu=tempaccu
        best_rstate=i

print(f"Best Accuracy {accu*100} found at random state {best_rstate} ")
# Out:
# Best Accuracy 94.23076923076923 found at random state 56

# %% [markdown]
# We see that the Gradient boosting classifier has the highest accuracy. We can finalise this model.

# %% [markdown]
# # Hypertuning the model

# %%
x_train,x_test,y_train,y_test=train_test_split(normalized_X,Y,test_size=0.20,random_state=56)
Best_Model = GradientBoostingClassifier()
parameters={"loss":['deviance', 'exponential'],"n_estimators":[100,200,300],"criterion":['friedman_mse', 'mse', 'mae']}
gs=GridSearchCV(Best_Model,parameters)
gs.fit(x_train,y_train)
gs.best_estimator_.get_params()
# Out:
# C:\Users\Sankalp\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# {'criterion': 'friedman_mse',
#  'init': None,
#  'learning_rate': 0.1,
#  'loss': 'exponential',
#  'max_depth': 3,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 300,
#  'n_iter_no_change': None,
#  'presort': 'auto',
#  'random_state': None,
#  'subsample': 1.0,
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# N_estimator values is not the default and says that the model will work best with 300 estimators

# %% [markdown]
# # Finalising the model

# %%
x_train,x_test,y_train,y_test=train_test_split(normalized_X,Y,test_size=0.25,random_state=56)
mod=GradientBoostingClassifier(n_estimators=300)
mod.fit(x_train,y_train)
y_pred=mod.predict(x_test)
tempaccu=accuracy_score(y_test,y_pred)
print(confusion_matrix(y_pred,y_test))
print(classification_report(y_pred,y_test))
# Out:
# [[22  3]
#  [ 4 23]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.86        25
#            1       0.88      0.85      0.87        27
#
#     accuracy                           0.87        52
#    macro avg       0.87      0.87      0.87        52
# weighted avg       0.87      0.87      0.87        52

# %%
from sklearn.model_selection import cross_val_score

# %%
score = cross_val_score(mod,X,Y,cv=30,scoring='accuracy').mean()
print("std: {}".format(score.std()))
print("cross_val_score: {}".format(score*100))
# Out:
# std: 0.0
# cross_val_score: 80.61507936507935

# %% [markdown]
# Our Model is neither overfitting nor underfitting

# %%
import joblib
joblib.dump(mod,'sonar_Grad_Boost_Classifier.pkl')
# Out:
# ['sonar_Grad_Boost_Classifier.pkl']
